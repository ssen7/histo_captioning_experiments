# %%
import time
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torchvision.transforms as transforms
from torch import nn
from torch.nn.utils.rnn import pack_padded_sequence
from models import Encoder, DecoderWithAttention
from dataloader import *
from utils import *
from nltk.translate.bleu_score import corpus_bleu

# %%
word_map=read_obj('./word_map.pickle')
# word_map

# %%
# Data parameters
# data_folder = '/media/ssd/caption data'  # folder with data files saved by create_input_files.py
df_path='/home/ss4yd/vision_transformer/captioning_vision_transformer/prepared_prelim_data_tokenized.pickle'
data_name = 'hipt_captioning_task'  # base name shared by data files

# Model parameters
emb_dim = 192  # dimension of word embeddings
encoder_dim=192
attention_dim = 192  # dimension of attention linear layers
decoder_dim = 512  # dimension of decoder RNN
dropout = 0.2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # sets device for model and PyTorch tensors
cudnn.benchmark = True  # set to true only if inputs to model are fixed size; otherwise lot of computational overhead

# Training parameters
start_epoch = 0
epochs = 120  # number of epochs to train for (if early stopping is not triggered)
epochs_since_improvement = 0  # keeps track of number of epochs since there's been an improvement in validation BLEU
batch_size = 32
workers = 1  # for data-loading; right now, only 1 works with h5py
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning
decoder_lr = 4e-4  # learning rate for decoder
grad_clip = 5.  # clip gradients at an absolute value of
alpha_c = 1.  # regularization parameter for 'doubly stochastic attention', as in the paper
best_bleu4 = 0.  # BLEU-4 score right now
print_freq = 100  # print training/validation stats every __ batches
fine_tune_encoder = False  # fine-tune encoder?
checkpoint = None  # path to checkpoint, None if none

# %%
def main():
    global best_bleu4, epochs_since_improvement, checkpoint, start_epoch, fine_tune_encoder, data_name, word_map

    if checkpoint is None:
        decoder = DecoderWithAttention(attention_dim=attention_dim,
                                       embed_dim=emb_dim,
                                       decoder_dim=decoder_dim,
                                       encoder_dim=encoder_dim,
                                       vocab_size=len(word_map),
                                       dropout=dropout,
                                       device=device)
        decoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, decoder.parameters()),
                                             lr=decoder_lr)
        encoder = Encoder()
    #     encoder.fine_tune(fine_tune_encoder)
        encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
                                             lr=encoder_lr) if fine_tune_encoder else None
    else:
            checkpoint = torch.load(checkpoint)
            start_epoch = checkpoint['epoch'] + 1
            epochs_since_improvement = checkpoint['epochs_since_improvement']
            best_bleu4 = checkpoint['bleu-4']
            decoder = checkpoint['decoder']
            decoder_optimizer = checkpoint['decoder_optimizer']
            encoder = checkpoint['encoder']
            encoder_optimizer = checkpoint['encoder_optimizer']
            if fine_tune_encoder is True and encoder_optimizer is None:
    #             encoder.fine_tune(fine_tune_encoder)
                encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
                                                     lr=encoder_lr)

    decoder = decoder.to(device)
    encoder = encoder.to(device)

    # Loss function
    criterion = nn.CrossEntropyLoss().to(device)

    train_loader = torch.utils.data.DataLoader(
            PreLoadedReps(df_path,'train'),
            batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)
    val_loader = torch.utils.data.DataLoader(
        PreLoadedReps(df_path,'val'),
        batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)

    for epoch in range(start_epoch, epochs):

        # Decay learning rate if there is no improvement for 8 consecutive epochs, and terminate training after 20
        if epochs_since_improvement == 20:
            break
        if epochs_since_improvement > 0 and epochs_since_improvement % 8 == 0:
            adjust_learning_rate(decoder_optimizer, 0.8)
            if fine_tune_encoder:
                adjust_learning_rate(encoder_optimizer, 0.8)

        # One epoch's training
        train(train_loader=train_loader,
              encoder=encoder,
              decoder=decoder,
              criterion=criterion,
              encoder_optimizer=encoder_optimizer,
              decoder_optimizer=decoder_optimizer,
              epoch=epoch)

        # One epoch's validation
        recent_bleu4 = validate(val_loader=val_loader,
                                encoder=encoder,
                                decoder=decoder,
                                criterion=criterion)

        # Check if there was an improvement
        is_best = recent_bleu4 > best_bleu4
        best_bleu4 = max(recent_bleu4, best_bleu4)
        if not is_best:
            epochs_since_improvement += 1
            print("\nEpochs since last improvement: %d\n" % (epochs_since_improvement,))
        else:
            epochs_since_improvement = 0

        # Save checkpoint
        save_checkpoint(data_name, epoch, epochs_since_improvement, encoder, decoder, encoder_optimizer,
                        decoder_optimizer, recent_bleu4, is_best)

# %%
def train(train_loader, encoder, decoder, criterion, encoder_optimizer, decoder_optimizer, epoch):
    """
    Performs one epoch's training.
    :param train_loader: DataLoader for training data
    :param encoder: encoder model
    :param decoder: decoder model
    :param criterion: loss layer
    :param encoder_optimizer: optimizer to update encoder's weights (if fine-tuning)
    :param decoder_optimizer: optimizer to update decoder's weights
    :param epoch: epoch number
    """

    decoder.train()  # train mode (dropout and batchnorm is used)
    encoder.train()

    batch_time = AverageMeter()  # forward prop. + back prop. time
    data_time = AverageMeter()  # data loading time
    losses = AverageMeter()  # loss (per word decoded)
    top5accs = AverageMeter()  # top5 accuracy

    start = time.time()

    # Batches
    for i, (imgs, caps, caplens) in enumerate(train_loader):
        data_time.update(time.time() - start)

        # Move to GPU, if available
        imgs = imgs.to(device)
        caps = caps.to(device)
        caplens = caplens.to(device)

        # Forward prop.
        imgs = encoder(imgs)
        scores, caps_sorted, decode_lengths, alphas, sort_ind = decoder(imgs, caps, caplens)

        # Since we decoded starting with <start>, the targets are all words after <start>, up to <end>
        targets = caps_sorted[:, 1:]

        # Remove timesteps that we didn't decode at, or are pads
        # pack_padded_sequence is an easy trick to do this
        scores, _,_,_ = pack_padded_sequence(scores, decode_lengths, batch_first=True)
        targets, _,_,_ = pack_padded_sequence(targets, decode_lengths, batch_first=True)

        # Calculate loss
        loss = criterion(scores, targets)

        # Add doubly stochastic attention regularization
        loss += alpha_c * ((1. - alphas.sum(dim=1)) ** 2).mean()

        # Back prop.
        decoder_optimizer.zero_grad()
        if encoder_optimizer is not None:
            encoder_optimizer.zero_grad()
        loss.backward()

        # Clip gradients
        if grad_clip is not None:
            clip_gradient(decoder_optimizer, grad_clip)
            if encoder_optimizer is not None:
                clip_gradient(encoder_optimizer, grad_clip)

        # Update weights
        decoder_optimizer.step()
        if encoder_optimizer is not None:
            encoder_optimizer.step()

        # Keep track of metrics
        top5 = accuracy(scores, targets, 5)
        losses.update(loss.item(), sum(decode_lengths))
        top5accs.update(top5, sum(decode_lengths))
        batch_time.update(time.time() - start)

        start = time.time()

        # Print status
        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Batch Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Data Load Time {data_time.val:.3f} ({data_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Top-5 Accuracy {top5.val:.3f} ({top5.avg:.3f})'.format(epoch, i, len(train_loader),
                                                                          batch_time=batch_time,
                                                                          data_time=data_time, loss=losses,
                                                                          top5=top5accs))


def validate(val_loader, encoder, decoder, criterion):
    """
    Performs one epoch's validation.
    :param val_loader: DataLoader for validation data.
    :param encoder: encoder model
    :param decoder: decoder model
    :param criterion: loss layer
    :return: BLEU-4 score
    """
    decoder.eval()  # eval mode (no dropout or batchnorm)
    if encoder is not None:
        encoder.eval()

    batch_time = AverageMeter()
    losses = AverageMeter()
    top5accs = AverageMeter()

    start = time.time()

    references = list()  # references (true captions) for calculating BLEU-4 score
    hypotheses = list()  # hypotheses (predictions)

    # explicitly disable gradient calculation to avoid CUDA memory error
    # solves the issue #57
    with torch.no_grad():
        # Batches
        for i, (imgs, caps, caplens, allcaps) in enumerate(val_loader):

            # Move to device, if available
            imgs = imgs.to(device)
            caps = caps.to(device)
            caplens = caplens.to(device)

            # Forward prop.
            if encoder is not None:
                imgs = encoder(imgs)
#             print(imgs.shape)
            scores, caps_sorted, decode_lengths, alphas, sort_ind = decoder(imgs, caps, caplens)

            # Since we decoded starting with <start>, the targets are all words after <start>, up to <end>
            targets = caps_sorted[:, 1:]

            # Remove timesteps that we didn't decode at, or are pads
            # pack_padded_sequence is an easy trick to do this
            scores_copy = scores.clone()
            scores, _,_,_ = pack_padded_sequence(scores, decode_lengths, batch_first=True)
            targets, _,_,_ = pack_padded_sequence(targets, decode_lengths, batch_first=True)

            # Calculate loss
            loss = criterion(scores, targets)

            # Add doubly stochastic attention regularization
            loss += alpha_c * ((1. - alphas.sum(dim=1)) ** 2).mean()

            # Keep track of metrics
            losses.update(loss.item(), sum(decode_lengths))
            top5 = accuracy(scores, targets, 5)
            top5accs.update(top5, sum(decode_lengths))
            batch_time.update(time.time() - start)

            start = time.time()

            if i % print_freq == 0:
                print('Validation: [{0}/{1}]\t'
                      'Batch Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                      'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                      'Top-5 Accuracy {top5.val:.3f} ({top5.avg:.3f})\t'.format(i, len(val_loader), batch_time=batch_time,
                                                                                loss=losses, top5=top5accs))

            # Store references (true captions), and hypothesis (prediction) for each image
            # If for n images, we have n hypotheses, and references a, b, c... for each image, we need -
            # references = [[ref1a, ref1b, ref1c], [ref2a, ref2b], ...], hypotheses = [hyp1, hyp2, ...]

            # References
            allcaps = allcaps[sort_ind]  # because images were sorted in the decoder
            for j in range(allcaps.shape[0]):
                img_caps = allcaps[j].tolist()
                img_captions = list(
                    map(lambda c: [w for w in c if w not in {word_map['<start>'], word_map['<pad>']}],
                        img_caps))  # remove <start> and pads
                references.append(img_captions)

            # Hypotheses
            _, preds = torch.max(scores_copy, dim=2)
            preds = preds.tolist()
            temp_preds = list()
            for j, p in enumerate(preds):
                temp_preds.append(preds[j][:decode_lengths[j]])  # remove pads
            preds = temp_preds
            hypotheses.extend(preds)

            assert len(references) == len(hypotheses)

        # Calculate BLEU-4 scores
        bleu4 = corpus_bleu(references, hypotheses)
        
        rev_word_map = {v: k for k, v in word_map.items()}
        
        ind=random.randint(0, len(references)-1)
        tref = references[ind]
        thyp = hypotheses[ind]
        print(thyp)
        print('Random reference length: {}, ind: {}'.format(len(references), ind))
        tref = [[rev_word_map[i] for i in x] for x in tref]
        thyp = [rev_word_map[i] for i in thyp]
        print('References: {}'.format(tref))
        print('\n---------------------------------------\n')
        print(thyp)
        print('\n---------------------------------------\n')

        print(
            '\n * LOSS - {loss.avg:.3f}, TOP-5 ACCURACY - {top5.avg:.3f}, BLEU-4 - {bleu}\n'.format(
                loss=losses,
                top5=top5accs,
                bleu=bleu4))

    return bleu4

# %%
if __name__ == '__main__':
    main()
# Out:
# Epoch: [0][0/40]	Batch Time 1.928 (1.928)	Data Load Time 1.780 (1.780)	Loss 199.5123 (199.5123)	Top-5 Accuracy 3.800 (3.800)
# Validation: [0/3]	Batch Time 0.209 (0.209)	Loss 136.4376 (136.4376)	Top-5 Accuracy 47.696 (47.696)
# /home/ss4yd/.local/lib/python3.8/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# [1, 2, 3, 3, 3, 650, 650, 650, 650, 650, 650, 650, 650, 650, 650]
# Random reference length: 65, ind: 41
# References: [['2', 'pieces', ';', 'congested', ',', 'includes', 'capsule', '(', 'target', 'is', '5mm', 'below', 'capsule', ')', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', ',', ',', '<end>', '<end>', '<end>', '<end>', '<end>', '<end>', '<end>', '<end>', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 162.493, TOP-5 ACCURACY - 48.285, BLEU-4 - 2.365110512942126e-78
#
# Epoch: [1][0/40]	Batch Time 0.141 (0.141)	Data Load Time 0.074 (0.074)	Loss 176.9534 (176.9534)	Top-5 Accuracy 45.387 (45.387)
# Validation: [0/3]	Batch Time 0.089 (0.089)	Loss 152.8171 (152.8171)	Top-5 Accuracy 50.900 (50.900)
# [1, 2, 16, 62, 3, 3, 650, 650, 650]
# Random reference length: 65, ind: 49
# References: [['2', 'pieces', ';', 'some', 'fibrosis', ',', 'pigmented', 'macrophages', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'spermatogenesis', ',', ',', '<end>', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.041, TOP-5 ACCURACY - 50.064, BLEU-4 - 0.0762082254020272
#
# Epoch: [2][0/40]	Batch Time 0.141 (0.141)	Data Load Time 0.073 (0.073)	Loss 165.0086 (165.0086)	Top-5 Accuracy 50.928 (50.928)
# Validation: [0/3]	Batch Time 0.089 (0.089)	Loss 155.4248 (155.4248)	Top-5 Accuracy 51.036 (51.036)
# [47, 2, 3, 230, 55, 3, 142, 164, 650]
# Random reference length: 65, ind: 18
# References: [['6', 'pieces', ',', 'all', 'muscularis', ';', 'good', 'specimens', '<end>']]
#
# ---------------------------------------
#
# ['6', 'pieces', ',', 'all', 'muscularis', ',', 'good', 'specimens', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.639, TOP-5 ACCURACY - 51.588, BLEU-4 - 0.08169901005134045
#
# Epoch: [3][0/40]	Batch Time 0.123 (0.123)	Data Load Time 0.074 (0.074)	Loss 140.8805 (140.8805)	Top-5 Accuracy 56.915 (56.915)
# Validation: [0/3]	Batch Time 0.093 (0.093)	Loss 184.1138 (184.1138)	Top-5 Accuracy 48.905 (48.905)
# [1, 2, 3, 6, 74, 650, 650]
# Random reference length: 65, ind: 26
# References: [['2', 'pieces', 'severe', 'acute', '<unk>', 'infarction', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'moderate', 'congestion', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 163.276, TOP-5 ACCURACY - 55.146, BLEU-4 - 0.08742623300545072
#
# Epoch: [4][0/40]	Batch Time 0.130 (0.130)	Data Load Time 0.074 (0.074)	Loss 173.4377 (173.4377)	Top-5 Accuracy 55.583 (55.583)
# Validation: [0/3]	Batch Time 0.091 (0.091)	Loss 183.3954 (183.3954)	Top-5 Accuracy 58.897 (58.897)
# [1, 2, 3, 4, 18, 25, 25, 25, 142, 25, 25, 3]
# Random reference length: 65, ind: 15
# References: [['2', 'pieces', ',', '~50', '%', 'interstitial', '<unk>', ',', 'evidence', 'of', 'atrophy', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'no', '%', 'fat', 'fat', 'fat', 'good', 'fat', 'fat', ',']
#
# ---------------------------------------
#
#
#  * LOSS - 161.203, TOP-5 ACCURACY - 59.212, BLEU-4 - 0.0870905032708234
#
#
# Epochs since last improvement: 1
#
# Epoch: [5][0/40]	Batch Time 0.147 (0.147)	Data Load Time 0.075 (0.075)	Loss 178.5833 (178.5833)	Top-5 Accuracy 65.128 (65.128)
# Validation: [0/3]	Batch Time 0.094 (0.094)	Loss 183.2068 (183.2068)	Top-5 Accuracy 56.280 (56.280)
# [1, 2, 16, 90, 74, 650, 650, 650, 650, 650, 648, 22, 650, 648, 648, 650, 650, 650]
# Random reference length: 65, ind: 35
# References: [['2', 'pieces', ';', 'severe', 'fibrosis', 'without', 'nodule', 'formation', 'consistent', 'with', 'cardiac', 'cirrhosis', ',', 'possible', '<unk>', '<unk>', '<unk>', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'severe', 'congestion', '<end>', '<end>', '<end>', '<end>', '<end>', '<unk>', ')', '<end>', '<unk>', '<unk>', '<end>', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.811, TOP-5 ACCURACY - 60.229, BLEU-4 - 0.09950052850405117
#
# Epoch: [6][0/40]	Batch Time 0.124 (0.124)	Data Load Time 0.075 (0.075)	Loss 165.0864 (165.0864)	Top-5 Accuracy 64.677 (64.677)
# Validation: [0/3]	Batch Time 0.089 (0.089)	Loss 175.1396 (175.1396)	Top-5 Accuracy 58.696 (58.696)
# [1, 2, 3, 24, 24, 86, 3]
# Random reference length: 65, ind: 54
# References: [['2', 'pieces', ';', 'mild', 'patchy', 'scarring', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'interstitial', 'interstitial', 'fibrosis', ',']
#
# ---------------------------------------
#
#
#  * LOSS - 161.992, TOP-5 ACCURACY - 63.024, BLEU-4 - 0.11989454358989138
#
# Epoch: [7][0/40]	Batch Time 0.130 (0.130)	Data Load Time 0.074 (0.074)	Loss 147.6922 (147.6922)	Top-5 Accuracy 69.681 (69.681)
# Validation: [0/3]	Batch Time 0.090 (0.090)	Loss 146.0744 (146.0744)	Top-5 Accuracy 65.517 (65.517)
# [1, 2, 3, 63, 63, 3, 648, 151, 38, 25, 3, 648, 38, 25, 3, 648, 3, 650]
# Random reference length: 65, ind: 5
# References: [['2', 'pieces', ';', 'calcific', 'atherosclerosis', ',', '1.5mm', 'attachment', 'of', 'fat', 'and', 'attachment', 'of', 'nerve', 'on', 'one', 'piece', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'atherosclerosis', 'atherosclerosis', ',', '<unk>', 'atherosis', 'of', 'fat', ',', '<unk>', 'of', 'fat', ',', '<unk>', ',', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.722, TOP-5 ACCURACY - 63.914, BLEU-4 - 0.10042393854121212
#
#
# Epochs since last improvement: 1
#
# Epoch: [8][0/40]	Batch Time 0.129 (0.129)	Data Load Time 0.075 (0.075)	Loss 156.5916 (156.5916)	Top-5 Accuracy 71.173 (71.173)
# Validation: [0/3]	Batch Time 0.091 (0.091)	Loss 149.1771 (149.1771)	Top-5 Accuracy 65.854 (65.854)
# [1, 2, 16, 90, 50, 86, 38, 50, 16, 648, 38, 650, 648, 18, 650]
# Random reference length: 65, ind: 9
# References: [['2', 'pieces', ';', 'fibrosis', 'and', 'lymphoid', 'infiltrate', 'consistent', 'with', 'Hashimoto', 'thyroiditis', 'with', 'nodular', 'goiter', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'severe', 'and', 'fibrosis', 'of', 'and', ';', '<unk>', 'of', '<end>', '<unk>', '%', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.603, TOP-5 ACCURACY - 64.422, BLEU-4 - 0.12842304500450635
#
# Epoch: [9][0/40]	Batch Time 0.138 (0.138)	Data Load Time 0.074 (0.074)	Loss 176.9179 (176.9179)	Top-5 Accuracy 76.942 (76.942)
# Validation: [0/3]	Batch Time 0.088 (0.088)	Loss 147.2638 (147.2638)	Top-5 Accuracy 66.756 (66.756)
# [1, 2, 3, 103, 119, 3, 103, 102, 20, 102, 22, 650]
# Random reference length: 65, ind: 45
# References: [['2', 'pieces', ';', 'fibrovascular', 'tissue', 'with', 'ductal', '<unk>', ':', 'gynecomastoid', 'changes', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'gynecomastoid', 'stromal', ',', 'gynecomastoid', 'ductal', '(', 'ductal', ')', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 186.333, TOP-5 ACCURACY - 65.057, BLEU-4 - 0.11184563874132114
#
#
# Epochs since last improvement: 1
#
# Epoch: [10][0/40]	Batch Time 0.132 (0.132)	Data Load Time 0.074 (0.074)	Loss 175.8378 (175.8378)	Top-5 Accuracy 75.490 (75.490)
# Validation: [0/3]	Batch Time 0.088 (0.088)	Loss 138.1001 (138.1001)	Top-5 Accuracy 68.579 (68.579)
# [1, 2, 16, 6, 74, 650]
# Random reference length: 65, ind: 60
# References: [['2', 'pieces', ';', 'severe', 'congestion', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'moderate', 'congestion', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.193, TOP-5 ACCURACY - 64.803, BLEU-4 - 0.12433569754788604
#
#
# Epochs since last improvement: 2
#
# Epoch: [11][0/40]	Batch Time 0.140 (0.140)	Data Load Time 0.074 (0.074)	Loss 174.4529 (174.4529)	Top-5 Accuracy 76.214 (76.214)
# Validation: [0/3]	Batch Time 0.092 (0.092)	Loss 175.5603 (175.5603)	Top-5 Accuracy 61.750 (61.750)
# [1, 2, 3, 6, 74, 86, 650, 86, 648, 648, 79, 650, 648, 648, 650, 650]
# Random reference length: 65, ind: 38
# References: [['2', 'pieces', ';', 'diffuse', 'interstitial', 'fibrosis', 'with', '<unk>', 'and', 'chronic', 'inflammation', ',', 'abundant', 'pigmented', 'macrophages', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'moderate', 'congestion', 'fibrosis', '<end>', 'fibrosis', '<unk>', '<unk>', 'inflammation', '<end>', '<unk>', '<unk>', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.241, TOP-5 ACCURACY - 65.057, BLEU-4 - 0.12393900265289357
#
#
# Epochs since last improvement: 3
# Epoch: [12][0/40]	Batch Time 0.131 (0.131)	Data Load Time 0.073 (0.073)	Loss 180.9724 (180.9724)	Top-5 Accuracy 80.929 (80.929)
# Validation: [0/3]	Batch Time 0.095 (0.095)	Loss 152.0077 (152.0077)	Top-5 Accuracy 67.769 (67.769)
# [47, 2, 3, 151, 151, 650, 650]
# Random reference length: 65, ind: 58
# References: [['6', 'pieces', ',', 'minimal', '<unk>', 'serosa', '<end>']]
#
# ---------------------------------------
#
# ['6', 'pieces', ',', 'atherosis', 'atherosis', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.232, TOP-5 ACCURACY - 66.836, BLEU-4 - 0.13648932277729614
#
# Epoch: [13][0/40]	Batch Time 0.133 (0.133)	Data Load Time 0.074 (0.074)	Loss 150.4352 (150.4352)	Top-5 Accuracy 83.467 (83.467)
# Validation: [0/3]	Batch Time 0.093 (0.093)	Loss 185.8270 (185.8270)	Top-5 Accuracy 65.865 (65.865)
# [1, 2, 16, 6, 50, 86, 38, 16, 16, 648, 38, 16, 648, 38, 650]
# Random reference length: 65, ind: 10
# References: [['2', 'pieces', ';', 'fibrosis', 'and', 'lymphoid', 'infiltrate', 'consistent', 'with', 'Hashimoto', 'thyroiditis', 'with', 'nodular', 'goiter', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'moderate', 'and', 'fibrosis', 'of', ';', ';', '<unk>', 'of', ';', '<unk>', 'of', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.931, TOP-5 ACCURACY - 67.344, BLEU-4 - 0.12700562315586517
#
#
# Epochs since last improvement: 1
#
# Epoch: [14][0/40]	Batch Time 0.133 (0.133)	Data Load Time 0.075 (0.075)	Loss 118.5218 (118.5218)	Top-5 Accuracy 85.799 (85.799)
# Validation: [0/3]	Batch Time 0.087 (0.087)	Loss 165.0191 (165.0191)	Top-5 Accuracy 64.394 (64.394)
# [1, 2, 3, 6, 74, 650, 650, 650]
# Random reference length: 65, ind: 52
# References: [['2', 'pieces', ',', 'marked', '<unk>', '<unk>', 'pneumonitis', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'moderate', 'congestion', '<end>', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.778, TOP-5 ACCURACY - 64.930, BLEU-4 - 0.12760812526002713
#
#
# Epochs since last improvement: 2
#
# Epoch: [15][0/40]	Batch Time 0.135 (0.135)	Data Load Time 0.075 (0.075)	Loss 191.8988 (191.8988)	Top-5 Accuracy 85.542 (85.542)
# Validation: [0/3]	Batch Time 0.092 (0.092)	Loss 194.3942 (194.3942)	Top-5 Accuracy 62.413 (62.413)
# [1, 2, 3, 4, 3, 650, 650, 143, 5, 650, 650, 143, 650, 650]
# Random reference length: 65, ind: 13
# References: [['2', 'pieces', ',', '<unk>', 'adipose', 'tissue', ',', 'no', 'fibrous', 'tissue/vessels', ';', 'excellent', 'specimen', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'no', ',', '<end>', '<end>', 'well', 'abnormalities', '<end>', '<end>', 'well', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 164.074, TOP-5 ACCURACY - 65.947, BLEU-4 - 0.12722584449554566
#
#
# Epochs since last improvement: 3
#
# Epoch: [16][0/40]	Batch Time 0.130 (0.130)	Data Load Time 0.075 (0.075)	Loss 141.4876 (141.4876)	Top-5 Accuracy 90.489 (90.489)
# Validation: [0/3]	Batch Time 0.093 (0.093)	Loss 203.2052 (203.2052)	Top-5 Accuracy 63.616 (63.616)
# [1, 2, 16, 6, 74, 650]
# Random reference length: 65, ind: 62
# References: [['2', 'pieces', ',', 'marked', 'congestion', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'moderate', 'congestion', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 166.000, TOP-5 ACCURACY - 66.836, BLEU-4 - 0.1434253927845868
#
# Epoch: [17][0/40]	Batch Time 0.127 (0.127)	Data Load Time 0.072 (0.072)	Loss 159.8681 (159.8681)	Top-5 Accuracy 89.231 (89.231)
# Validation: [0/3]	Batch Time 0.088 (0.088)	Loss 158.2852 (158.2852)	Top-5 Accuracy 65.810 (65.810)
# [1, 2, 16, 90, 243, 20, 378, 22, 306, 22, 315, 22, 3, 129, 650, 283, 175, 175, 86, 650, 650, 283, 296, 650]
# Random reference length: 65, ind: 1
# References: [['2', 'pieces', ';', 'includes', 'capsule', '(', 'target', 'is', '1cm', 'below', 'capsule', ')', ',', 'cirrhosis', 'with', 'severe', 'microvesicular', 'and', '<unk>', 'steatosis', ',', 'Mallory', '<unk>', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'severe', 'cirrhosis', '(', 'target', ')', '1', ')', 'capsule', ')', ',', 'some', '<end>', '>', 'steatosis', 'steatosis', 'fibrosis', '<end>', '<end>', '>', 'proliferation', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 159.914, TOP-5 ACCURACY - 65.438, BLEU-4 - 0.13848140784842605
#
#
# Epochs since last improvement: 1
#
# Epoch: [18][0/40]	Batch Time 0.132 (0.132)	Data Load Time 0.075 (0.075)	Loss 177.7327 (177.7327)	Top-5 Accuracy 93.154 (93.154)
# Validation: [0/3]	Batch Time 0.087 (0.087)	Loss 119.7929 (119.7929)	Top-5 Accuracy 67.456 (67.456)
# [1, 2, 3, 4, 334, 3, 4, 38, 3, 7, 648, 3]
# Random reference length: 65, ind: 9
# References: [['2', 'pieces', ',', 'multinodular', 'goiter', ',', 'colloid', 'nodules', 'up', 'to', '<unk>', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'no', 'colloid', ',', 'no', 'of', ',', 'to', '<unk>', ',']
#
# ---------------------------------------
#
#
#  * LOSS - 165.418, TOP-5 ACCURACY - 66.074, BLEU-4 - 0.1236500069339845
#
#
# Epochs since last improvement: 2
#
# Epoch: [19][0/40]	Batch Time 0.133 (0.133)	Data Load Time 0.074 (0.074)	Loss 153.1575 (153.1575)	Top-5 Accuracy 92.428 (92.428)
# Validation: [0/3]	Batch Time 0.093 (0.093)	Loss 156.5638 (156.5638)	Top-5 Accuracy 66.842 (66.842)
# [47, 2, 3, 230, 3, 142, 171, 3, 18, 522, 522, 101, 55, 55, 650, 648, 650, 650]
# Random reference length: 65, ind: 4
# References: [['6', 'pieces', ',', 'well-preserved', ',', 'lymphoid', 'aggregates', '~10', '%', 'total', ',', 'best', 'for', 'LCM', 'or', 'TMA', 'studies', '<end>']]
#
# ---------------------------------------
#
# ['6', 'pieces', ',', 'all', ',', 'good', 'adherent', ',', '%', 'thickness', 'thickness', 'mild', 'muscularis', 'muscularis', '<end>', '<unk>', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 159.990, TOP-5 ACCURACY - 66.201, BLEU-4 - 0.13740170246134503
#
#
# Epochs since last improvement: 3
#
# Epoch: [20][0/40]	Batch Time 0.141 (0.141)	Data Load Time 0.073 (0.073)	Loss 165.7596 (165.7596)	Top-5 Accuracy 91.603 (91.603)
# Validation: [0/3]	Batch Time 0.087 (0.087)	Loss 172.8674 (172.8674)	Top-5 Accuracy 64.720 (64.720)
# [47, 2, 3, 230, 55, 3, 142, 164, 650]
# Random reference length: 65, ind: 21
# References: [['6', 'pieces', ',', 'all', 'muscularis', ';', 'good', 'specimens', '<end>']]
#
# ---------------------------------------
#
# ['6', 'pieces', ',', 'all', 'muscularis', ',', 'good', 'specimens', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 188.663, TOP-5 ACCURACY - 65.947, BLEU-4 - 0.13571484019739416
#
#
# Epochs since last improvement: 4
#
# Epoch: [21][0/40]	Batch Time 0.128 (0.128)	Data Load Time 0.074 (0.074)	Loss 192.8886 (192.8886)	Top-5 Accuracy 94.131 (94.131)
# Validation: [0/3]	Batch Time 0.087 (0.087)	Loss 148.8576 (148.8576)	Top-5 Accuracy 68.158 (68.158)
# [1, 2, 3, 648, 52, 5, 650]
# Random reference length: 65, ind: 23
# References: [['2', 'pieces', 'cardiac', '<unk>', 'no', 'abnormalities', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', '<unk>', 'with', 'abnormalities', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.060, TOP-5 ACCURACY - 66.328, BLEU-4 - 0.14315651940441076
#
#
# Epochs since last improvement: 5
#
# Epoch: [22][0/40]	Batch Time 0.137 (0.137)	Data Load Time 0.075 (0.075)	Loss 178.3665 (178.3665)	Top-5 Accuracy 94.103 (94.103)
# Validation: [0/3]	Batch Time 0.087 (0.087)	Loss 143.9371 (143.9371)	Top-5 Accuracy 72.032 (72.032)
# [1, 2, 16, 94, 419, 42, 3]
# Random reference length: 65, ind: 64
# References: [['1', 'pieces', ';', 'many', 'pigmented', 'macrophages', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'emphysema', 'alveolar', 'macrophages', ',']
#
# ---------------------------------------
#
#
#  * LOSS - 161.234, TOP-5 ACCURACY - 68.107, BLEU-4 - 0.14145416302196392
#
#
# Epochs since last improvement: 6
#
# Epoch: [23][0/40]	Batch Time 0.123 (0.123)	Data Load Time 0.074 (0.074)	Loss 149.0634 (149.0634)	Top-5 Accuracy 94.517 (94.517)
# Validation: [0/3]	Batch Time 0.088 (0.088)	Loss 146.0547 (146.0547)	Top-5 Accuracy 68.947 (68.947)
# [1, 2, 16, 149, 14, 15, 18, 381, 19, 32, 21, 16]
# Random reference length: 65, ind: 14
# References: [['2', 'pieces', ',', 'mesothelial', '<unk>', '~10', '%', 'total', ',', 'rep', 'delineated', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'minimal', 'mesothelial', 'hyperplasia', '%', 'fibrovascular', 'tissue', 'rep', 'delineated', ';']
#
# ---------------------------------------
#
#
#  * LOSS - 162.116, TOP-5 ACCURACY - 66.836, BLEU-4 - 0.14103622298962354
#
#
# Epochs since last improvement: 7
# Epoch: [24][0/40]	Batch Time 0.141 (0.141)	Data Load Time 0.074 (0.074)	Loss 157.5320 (157.5320)	Top-5 Accuracy 94.211 (94.211)
# Validation: [0/3]	Batch Time 0.092 (0.092)	Loss 168.8684 (168.8684)	Top-5 Accuracy 64.450 (64.450)
# [1, 2, 3, 4, 334, 650, 191, 21, 21, 21, 650]
# Random reference length: 65, ind: 16
# References: [['2', 'pieces', ',', '<unk>', 'thyroiditis', ',', 'rep', 'lymphoid', 'aggregates', 'delineated', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'no', 'colloid', '<end>', 'few', 'delineated', 'delineated', 'delineated', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 166.054, TOP-5 ACCURACY - 67.598, BLEU-4 - 0.14508619218381924
#
# Epoch: [25][0/40]	Batch Time 0.138 (0.138)	Data Load Time 0.073 (0.073)	Loss 145.7591 (145.7591)	Top-5 Accuracy 97.347 (97.347)
# Validation: [0/3]	Batch Time 0.087 (0.087)	Loss 156.6779 (156.6779)	Top-5 Accuracy 68.123 (68.123)
# [1, 2, 3, 6, 3, 72, 86, 50, 129, 185, 79, 650, 378, 315, 22, 22, 650]
# Random reference length: 65, ind: 38
# References: [['2', 'pieces', ';', 'steatosis', ',', 'bridging', 'fibrosis', ',', 'and', 'chronic', 'inflammation', '(', '?', '<unk>', 'steatohepatitis', ')', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'moderate', ',', 'includes', 'fibrosis', 'and', 'some', 'bridging', 'inflammation', '<end>', 'target', 'capsule', ')', ')', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.069, TOP-5 ACCURACY - 67.471, BLEU-4 - 0.1529900878312929
#
# Epoch: [26][0/40]	Batch Time 0.136 (0.136)	Data Load Time 0.074 (0.074)	Loss 171.7014 (171.7014)	Top-5 Accuracy 97.674 (97.674)
# Validation: [0/3]	Batch Time 0.093 (0.093)	Loss 156.0854 (156.0854)	Top-5 Accuracy 61.600 (61.600)
# [1, 2, 16, 62, 648, 648, 648, 650, 650, 86, 650, 650]
# Random reference length: 65, ind: 12
# References: [['2', 'pieces', ';', 'marked', '<unk>', 'in', 'spermatogenesis', ';', 'some', 'tubules', 'hyalinized', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'spermatogenesis', '<unk>', '<unk>', '<unk>', '<end>', '<end>', 'fibrosis', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.079, TOP-5 ACCURACY - 65.693, BLEU-4 - 0.13537264820439304
#
#
# Epochs since last improvement: 1
#
# Epoch: [27][0/40]	Batch Time 0.131 (0.131)	Data Load Time 0.075 (0.075)	Loss 169.4031 (169.4031)	Top-5 Accuracy 97.343 (97.343)
# Validation: [0/3]	Batch Time 0.090 (0.090)	Loss 145.6581 (145.6581)	Top-5 Accuracy 71.585 (71.585)
# [47, 2, 3, 143, 3, 142, 147, 3, 147, 18, 147, 431, 32, 39, 650]
# Random reference length: 65, ind: 42
# References: [['6', 'pieces', ',', 'well-preserved', ',', 'lymphoid', '<unk>', 'are', '~20', '%', 'total', ',', 'good', 'specimen', '<end>']]
#
# ---------------------------------------
#
# ['6', 'pieces', ',', 'well', ',', 'good', 'lymphoid', ',', 'lymphoid', '%', 'lymphoid', 'aggregates', 'rep', 'specimen', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.884, TOP-5 ACCURACY - 66.201, BLEU-4 - 0.12659697589834112
#
#
# Epochs since last improvement: 2
#
# Epoch: [28][0/40]	Batch Time 0.130 (0.130)	Data Load Time 0.075 (0.075)	Loss 158.8396 (158.8396)	Top-5 Accuracy 97.468 (97.468)
# Validation: [0/3]	Batch Time 0.092 (0.092)	Loss 174.2674 (174.2674)	Top-5 Accuracy 65.327 (65.327)
# [1, 2, 3, 6, 3, 72, 86, 50, 129, 185, 79, 650, 441, 315, 22, 22, 650]
# Random reference length: 65, ind: 38
# References: [['2', 'pieces', ';', 'steatosis', ',', 'bridging', 'fibrosis', ',', 'and', 'chronic', 'inflammation', '(', '?', '<unk>', 'steatohepatitis', ')', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'moderate', ',', 'includes', 'fibrosis', 'and', 'some', 'bridging', 'inflammation', '<end>', 'c/w', 'capsule', ')', ')', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.481, TOP-5 ACCURACY - 66.709, BLEU-4 - 0.14534066415457647
#
#
# Epochs since last improvement: 3
#
# Epoch: [29][0/40]	Batch Time 0.126 (0.126)	Data Load Time 0.074 (0.074)	Loss 178.7532 (178.7532)	Top-5 Accuracy 98.595 (98.595)
# Validation: [0/3]	Batch Time 0.086 (0.086)	Loss 152.5587 (152.5587)	Top-5 Accuracy 68.475 (68.475)
# [1, 2, 3, 648, 3, 5, 650]
# Random reference length: 65, ind: 53
# References: [['2', 'pieces', 'cardiac', '<unk>', 'no', 'abnormalities', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', '<unk>', ',', 'abnormalities', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.670, TOP-5 ACCURACY - 67.726, BLEU-4 - 0.14115708305663516
#
#
# Epochs since last improvement: 4
#
# Epoch: [30][0/40]	Batch Time 0.139 (0.139)	Data Load Time 0.074 (0.074)	Loss 184.6381 (184.6381)	Top-5 Accuracy 97.877 (97.877)
# Validation: [0/3]	Batch Time 0.091 (0.091)	Loss 160.7019 (160.7019)	Top-5 Accuracy 64.737 (64.737)
# [1, 2, 16, 43, 50, 56, 3, 78, 3, 129, 57, 650]
# Random reference length: 65, ind: 13
# References: [['2', 'pieces', ';', 'congestion', ',', 'edema', ',', 'fibrin', ',', 'patchy', 'pneumonia', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'patchy', 'and', 'edema', ',', 'focal', ',', 'some', 'chronic', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.943, TOP-5 ACCURACY - 66.328, BLEU-4 - 0.14243823821285329
#
#
# Epochs since last improvement: 5
#
# Epoch: [31][0/40]	Batch Time 0.132 (0.132)	Data Load Time 0.072 (0.072)	Loss 172.7168 (172.7168)	Top-5 Accuracy 98.044 (98.044)
# Validation: [0/3]	Batch Time 0.094 (0.094)	Loss 159.5830 (159.5830)	Top-5 Accuracy 68.074 (68.074)
# [1, 2, 16, 124, 85, 3, 648, 16, 16, 366, 650, 366, 18, 25, 25, 650]
# Random reference length: 65, ind: 41
# References: [['2', 'pieces', ';', 'Hashimoto', 'thyroiditis', 'with', 'moderate', 'fibrosis', ';', 'each', 'has', '20', '%', 'peripheral', 'fat', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'extensive', 'thyroiditis', ',', '<unk>', ';', ';', 'other', '<end>', 'other', '%', 'fat', 'fat', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 162.175, TOP-5 ACCURACY - 67.217, BLEU-4 - 0.14377273104785798
#
#
# Epochs since last improvement: 6
#
# Epoch: [32][0/40]	Batch Time 0.150 (0.150)	Data Load Time 0.075 (0.075)	Loss 175.6797 (175.6797)	Top-5 Accuracy 98.259 (98.259)
# Validation: [0/3]	Batch Time 0.091 (0.091)	Loss 203.3267 (203.3267)	Top-5 Accuracy 67.294 (67.294)
# [1, 2, 3, 90, 419, 50, 50, 86, 86, 74, 79, 650, 74, 648, 648, 650]
# Random reference length: 65, ind: 37
# References: [['2', 'pieces', ';', 'diffuse', 'interstitial', 'fibrosis', 'with', '<unk>', 'and', 'chronic', 'inflammation', ',', 'abundant', 'pigmented', 'macrophages', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'severe', 'alveolar', 'and', 'and', 'fibrosis', 'fibrosis', 'congestion', 'inflammation', '<end>', 'congestion', '<unk>', '<unk>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 164.930, TOP-5 ACCURACY - 66.963, BLEU-4 - 0.12575322444884085
#
#
# Epochs since last improvement: 7
#
# Epoch: [33][0/40]	Batch Time 0.129 (0.129)	Data Load Time 0.074 (0.074)	Loss 117.8962 (117.8962)	Top-5 Accuracy 99.410 (99.410)
# Validation: [0/3]	Batch Time 0.092 (0.092)	Loss 179.1727 (179.1727)	Top-5 Accuracy 66.585 (66.585)
# [1, 2, 16, 101, 74, 52, 52, 52, 650]
# Random reference length: 65, ind: 21
# References: [['2', 'pieces', ',', 'diffuse', '<unk>', '<unk>', '<unk>', 'steatosis', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'mild', 'congestion', 'with', 'with', 'with', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.930, TOP-5 ACCURACY - 66.201, BLEU-4 - 0.12319041880076345
#
#
# Epochs since last improvement: 8
#
#
# DECAYING learning rate.
# The new learning rate is 0.000320
#
# Epoch: [34][0/40]	Batch Time 0.156 (0.156)	Data Load Time 0.075 (0.075)	Loss 180.2388 (180.2388)	Top-5 Accuracy 99.239 (99.239)
# Validation: [0/3]	Batch Time 0.091 (0.091)	Loss 182.6111 (182.6111)	Top-5 Accuracy 65.842 (65.842)
# [1, 2, 16, 90, 74, 650]
# Random reference length: 65, ind: 27
# References: [['2', 'pieces', ';', 'severe', 'congestion', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'severe', 'congestion', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 162.159, TOP-5 ACCURACY - 67.471, BLEU-4 - 0.1407386100488222
#
#
# Epochs since last improvement: 9
# Epoch: [35][0/40]	Batch Time 0.123 (0.123)	Data Load Time 0.073 (0.073)	Loss 123.9988 (123.9988)	Top-5 Accuracy 97.983 (97.983)
# Validation: [0/3]	Batch Time 0.092 (0.092)	Loss 154.8651 (154.8651)	Top-5 Accuracy 64.785 (64.785)
# [1, 2, 3, 90, 419, 86, 50, 86, 220, 180, 79, 650, 648, 648, 648, 650]
# Random reference length: 65, ind: 41
# References: [['2', 'pieces', ';', 'diffuse', 'interstitial', 'fibrosis', 'with', '<unk>', 'and', 'chronic', 'inflammation', ',', 'abundant', 'pigmented', 'macrophages', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'severe', 'alveolar', 'fibrosis', 'and', 'fibrosis', 'pneumonia', 'hemorrhage', 'inflammation', '<end>', '<unk>', '<unk>', '<unk>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.692, TOP-5 ACCURACY - 66.709, BLEU-4 - 0.13074555838787116
#
#
# Epochs since last improvement: 10
#
# Epoch: [36][0/40]	Batch Time 0.135 (0.135)	Data Load Time 0.073 (0.073)	Loss 197.5754 (197.5754)	Top-5 Accuracy 99.535 (99.535)
# Validation: [0/3]	Batch Time 0.092 (0.092)	Loss 161.3959 (161.3959)	Top-5 Accuracy 63.710 (63.710)
# [1, 2, 3, 4, 648, 3, 4, 38, 38, 650]
# Random reference length: 65, ind: 15
# References: [['2', 'pieces', ',', 'marked', 'autolysis', ',', '<unk>', 'debris/fibrous', 'tissue', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'no', '<unk>', ',', 'no', 'of', 'of', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.179, TOP-5 ACCURACY - 66.836, BLEU-4 - 0.13818465318171372
#
#
# Epochs since last improvement: 11
#
# Epoch: [37][0/40]	Batch Time 0.132 (0.132)	Data Load Time 0.075 (0.075)	Loss 173.3719 (173.3719)	Top-5 Accuracy 99.506 (99.506)
# Validation: [0/3]	Batch Time 0.089 (0.089)	Loss 145.7844 (145.7844)	Top-5 Accuracy 67.553 (67.553)
# [1, 2, 3, 74, 93, 93, 650]
# Random reference length: 65, ind: 55
# References: [['2', 'pieces', 'severe', 'acute', '<unk>', 'infarction', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'congestion', 'passive', 'passive', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.771, TOP-5 ACCURACY - 66.836, BLEU-4 - 0.1409399577926983
#
#
# Epochs since last improvement: 12
#
# Epoch: [38][0/40]	Batch Time 0.153 (0.153)	Data Load Time 0.074 (0.074)	Loss 158.2059 (158.2059)	Top-5 Accuracy 99.185 (99.185)
# Validation: [0/3]	Batch Time 0.091 (0.091)	Loss 159.5491 (159.5491)	Top-5 Accuracy 65.707 (65.707)
# [47, 2, 3, 84, 85, 3, 648, 16, 16, 366, 650, 366, 18, 25, 25, 650]
# Random reference length: 65, ind: 5
# References: [['2', 'pieces', ';', 'Hashimoto', 'thyroiditis', 'with', 'moderate', 'fibrosis', ';', 'each', 'has', '20', '%', 'peripheral', 'fat', '<end>']]
#
# ---------------------------------------
#
# ['6', 'pieces', ',', 'Hashimoto', 'thyroiditis', ',', '<unk>', ';', ';', 'other', '<end>', 'other', '%', 'fat', 'fat', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.659, TOP-5 ACCURACY - 66.201, BLEU-4 - 0.13986229458279242
#
#
# Epochs since last improvement: 13
#
# Epoch: [39][0/40]	Batch Time 0.142 (0.142)	Data Load Time 0.074 (0.074)	Loss 194.9220 (194.9220)	Top-5 Accuracy 98.789 (98.789)
# Validation: [0/3]	Batch Time 0.089 (0.089)	Loss 160.2419 (160.2419)	Top-5 Accuracy 64.122 (64.122)
# [1, 71, 16, 129, 439, 42, 3]
# Random reference length: 65, ind: 52
# References: [['1', 'pieces', ';', 'many', 'pigmented', 'macrophages', '<end>']]
#
# ---------------------------------------
#
# ['2', 'piece', ';', 'some', 'pigmented', 'macrophages', ',']
#
# ---------------------------------------
#
#
#  * LOSS - 161.368, TOP-5 ACCURACY - 66.074, BLEU-4 - 0.13926853740655318
#
#
# Epochs since last improvement: 14
#
# Epoch: [40][0/40]	Batch Time 0.138 (0.138)	Data Load Time 0.076 (0.076)	Loss 127.4986 (127.4986)	Top-5 Accuracy 99.422 (99.422)
# Validation: [0/3]	Batch Time 0.088 (0.088)	Loss 151.4426 (151.4426)	Top-5 Accuracy 71.277 (71.277)
# [1, 2, 16, 119, 38, 119, 15, 3, 78, 15, 650, 78, 38, 187, 187, 650]
# Random reference length: 65, ind: 7
# References: [['2', 'pieces', ';', 'sloughing', 'of', 'glandular', 'epithelium', ',', 'transitional', 'metaplasia', ',', 'focus', 'of', 'seminal', 'vesicle', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ';', 'stromal', 'of', 'stromal', 'hyperplasia', ',', 'focal', 'hyperplasia', '<end>', 'focal', 'of', 'epithelium', 'epithelium', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 160.588, TOP-5 ACCURACY - 66.201, BLEU-4 - 0.13683214091879028
#
#
# Epochs since last improvement: 15
#
# Epoch: [41][0/40]	Batch Time 0.140 (0.140)	Data Load Time 0.074 (0.074)	Loss 119.4110 (119.4110)	Top-5 Accuracy 100.000 (100.000)
# Validation: [0/3]	Batch Time 0.092 (0.092)	Loss 173.4894 (173.4894)	Top-5 Accuracy 61.654 (61.654)
# [1, 2, 3, 3, 62, 62, 650]
# Random reference length: 65, ind: 55
# References: [['2', 'fragmented', 'pieces', ';', 'active', 'spermatogenesis', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', ',', 'spermatogenesis', 'spermatogenesis', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 161.246, TOP-5 ACCURACY - 65.693, BLEU-4 - 0.1368604904435281
#
#
# Epochs since last improvement: 16
#
#
# DECAYING learning rate.
# The new learning rate is 0.000256
#
# Epoch: [42][0/40]	Batch Time 0.144 (0.144)	Data Load Time 0.075 (0.075)	Loss 214.9929 (214.9929)	Top-5 Accuracy 100.000 (100.000)
# Validation: [0/3]	Batch Time 0.084 (0.084)	Loss 114.2323 (114.2323)	Top-5 Accuracy 71.471 (71.471)
# [1, 2, 3, 90, 314, 3, 648, 38, 650, 650, 648, 38, 650, 650, 45, 650, 650, 650]
# Random reference length: 65, ind: 1
# References: [['2', 'pieces', ';', 'severe', 'fibrosis', 'without', 'nodule', 'formation', 'consistent', 'with', 'cardiac', 'cirrhosis', ',', 'possible', '<unk>', '<unk>', '<unk>', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'severe', 'central', ',', '<unk>', 'of', '<end>', '<end>', '<unk>', 'of', '<end>', '<end>', 'focus', '<end>', '<end>', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 171.489, TOP-5 ACCURACY - 66.455, BLEU-4 - 0.13475336041842292
#
#
# Epochs since last improvement: 17
#
# Epoch: [43][0/40]	Batch Time 0.142 (0.142)	Data Load Time 0.074 (0.074)	Loss 202.2607 (202.2607)	Top-5 Accuracy 100.000 (100.000)
# Validation: [0/3]	Batch Time 0.088 (0.088)	Loss 126.1280 (126.1280)	Top-5 Accuracy 71.552 (71.552)
# [1, 2, 3, 8, 74, 650]
# Random reference length: 65, ind: 25
# References: [['2', 'pieces', ',', 'marked', 'congestion', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'marked', 'congestion', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 165.347, TOP-5 ACCURACY - 65.820, BLEU-4 - 0.1288834184113116
#
#
# Epochs since last improvement: 18
#
# Epoch: [44][0/40]	Batch Time 0.155 (0.155)	Data Load Time 0.075 (0.075)	Loss 224.0675 (224.0675)	Top-5 Accuracy 100.000 (100.000)
# Validation: [0/3]	Batch Time 0.088 (0.088)	Loss 179.5293 (179.5293)	Top-5 Accuracy 67.062 (67.062)
# [1, 2, 3, 6, 7, 648, 18, 648, 3, 648, 648, 648, 25, 3, 648, 86, 650, 154, 650]
# Random reference length: 65, ind: 3
# References: [['2', 'pieces', ',', 'up', 'to', '70', '%', 'fat', '(', 'attached', 'and', 'internal', ')', ',', 'some', 'fibrosis', 'and', 'atrophy', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'moderate', 'to', '<unk>', '%', '<unk>', ',', '<unk>', '<unk>', '<unk>', 'fat', ',', '<unk>', 'fibrosis', '<end>', 'Islets', '<end>']
#
# ---------------------------------------
#
#
#  * LOSS - 163.486, TOP-5 ACCURACY - 65.693, BLEU-4 - 0.12665538282317337
#
#
# Epochs since last improvement: 19
#
# Epoch: [45][0/40]	Batch Time 0.126 (0.126)	Data Load Time 0.075 (0.075)	Loss 142.1281 (142.1281)	Top-5 Accuracy 99.735 (99.735)
# Validation: [0/3]	Batch Time 0.084 (0.084)	Loss 145.3045 (145.3045)	Top-5 Accuracy 65.633 (65.633)
# [1, 2, 3, 70, 52, 52, 648, 648, 648, 38, 25, 3, 306, 18, 22, 3, 178, 52]
# Random reference length: 65, ind: 2
# References: [['2', 'pieces', ',', 'one', 'piece', 'includes', '3', 'mm', 'attachment', 'of', 'fat', '(', '50', '%', ')', ',', 'atherosclerosis', '<end>']]
#
# ---------------------------------------
#
# ['2', 'pieces', ',', 'one', 'with', 'with', '<unk>', '<unk>', '<unk>', 'of', 'fat', ',', '1', '%', ')', ',', 'second', 'with']
#
# ---------------------------------------
#
#
#  * LOSS - 161.387, TOP-5 ACCURACY - 65.947, BLEU-4 - 0.13096066774111373
#
#
# Epochs since last improvement: 20
